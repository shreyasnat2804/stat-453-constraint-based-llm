# %%
# Cell 1 — clone your repo
# !git clone https://github.com/shreyasnat2804/stat-453-constraint-based-llm.git
# %cd stat-453-constraint-based-llm
# Out:
# Cloning into 'stat-453-constraint-based-llm'...
# remote: Enumerating objects: 205, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (16/16), done.
# remote: Total 205 (delta 6), reused 11 (delta 3), pack-reused 184 (from 1)
# Receiving objects: 100% (205/205), 123.93 MiB | 11.28 MiB/s, done.
# Resolving deltas: 100% (75/75), done.
# /Users/markaashish/Desktop/STAT 453/stat-453-constraint-based-llm/stat-453-constraint-based-llm

# %%
# Cell 2 — install deps
# !pip install transformers datasets accelerate huggingface_hub -q

# %%
# !nvidia-smi
# Out:
# zsh:1: command not found: nvidia-smi

# %%
# Out:
# ERROR: Could not find a version that satisfies the requirement nvidea-smi (from versions: none)
# ERROR: No matching distribution found for nvidea-smi
# Note: you may need to restart the kernel to use updated packages.
